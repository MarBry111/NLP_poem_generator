# %%
import pandas as pd
import numpy as np
import spacy

import requests

import re

# %% [markdown]
# Simple code to scrapp the rhymes from the [rymowanie.pl](https://rymowanie.pl) website

# %%
getpage= requests.get('https://rymowanie.pl/rymy/zdrowie/')

#<a class="load_word" href="../../rymy/zawiłość/">zawiłość</a>
match = re.findall(r'<a class="load_word" href="../../rymy/[\w]+/">([\w]+)</a>', getpage.text)

match
# Out:
# ['Azerowie',
#  'mrowie',
#  'Wejherowie',
#  'ostrowie',
#  'belfrowie',
#  'honorowie',
#  'laufrowie',
#  'Apolinarowie',
#  'Batorowie',
#  'Dezyderowie',
#  'Hilarowie',
#  'Januarowie',
#  'Ksawerowie',
#  'Makarowie',
#  'Onufrowie',
#  'podmajstrowie',
#  'Walerowie',
#  'wzorowie',
#  'hetajrowie',
#  'Popowie',
#  'mózgowie',
#  'przysłowie',
#  'listowie',
#  'pogłowie',
#  'posłowie',
#  'pustkowie',
#  'Baranowie',
#  'wodogłowie',
#  'sitowie',
#  'achajowie',
#  'bezgłowie',
#  'głoskowie',
#  'inkowie',
#  'międzymózgowie',
#  'niepokalanowie',
#  'pogotowie',
#  'przodomózgowie',
#  'śródmózgowie',
#  'Aleksowie',
#  'Ariowie',
#  'Arkadowie',
#  'batiuszkowie',
#  'Bieńkowie',
#  'Bonifacowie',
#  'Bońkowie',
#  'Czernowie',
#  'duchowie',
#  'elektropogotowie',
#  'Eustachowie',
#  'Germanowie',
#  'gęstowie',
#  'Grześkowie',
#  'Hellenowie',
#  'Heńkowie',
#  'Innocentowie',
#  'Jacentowie',
#  'Jaśkowie',
#  'jednorazowie',
#  'Konstantowie',
#  'Korfantowie',
# ...
